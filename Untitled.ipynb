# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Dataset path and parameters
dataset_path = r"C:\FlowersDataset"
batch_size = 32
img_size = (150, 150)

# %%
train_dataset = keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 1714 files belonging to 2 classes.
# Using 1372 files for training.

# %%
validation_dataset = keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 1714 files belonging to 2 classes.
# Using 342 files for validation.

# %%
# Get class names
class_names = train_dataset.class_names
print("Class names:", class_names)
# Out:
# Class names: ['sunflower', 'tulip']

# %%
# Visualize class distribution
train_labels = np.concatenate([y for x, y in train_dataset], axis=0)
unique_labels, label_counts = np.unique(train_labels, return_counts=True)
label_df = pd.DataFrame({'Label': unique_labels, 'Count': label_counts})

plt.figure(figsize=(10, 5))
sns.barplot(data=label_df, x="Label", y="Count", hue="Label", palette="viridis")
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Distribution of Sunflower and Tulip Images")
plt.show()

# %%
# Build the model with Input layer
model = keras.Sequential([
    keras.layers.Input(shape=(150, 150, 3)),
    keras.layers.Rescaling(1.0 / 255),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D(2, 2),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D(2, 2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(train_dataset, epochs=10, validation_data=validation_dataset)
# Out:
# Epoch 1/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 246ms/step - accuracy: 0.6522 - loss: 1.0707 - val_accuracy: 0.8480 - val_loss: 0.3515
# Epoch 2/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 0.8598 - loss: 0.3303 - val_accuracy: 0.8830 - val_loss: 0.2840
# Epoch 3/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.9124 - loss: 0.2562 - val_accuracy: 0.8538 - val_loss: 0.3240
# Epoch 4/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 0.9453 - loss: 0.1602 - val_accuracy: 0.9094 - val_loss: 0.2847
# Epoch 5/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.9537 - loss: 0.1398 - val_accuracy: 0.8918 - val_loss: 0.3060
# Epoch 6/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 231ms/step - accuracy: 0.9717 - loss: 0.0800 - val_accuracy: 0.8830 - val_loss: 0.3432
# Epoch 7/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 0.9957 - loss: 0.0275 - val_accuracy: 0.8830 - val_loss: 0.3835
# Epoch 8/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8860 - val_loss: 0.3928
# Epoch 9/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 0.8889 - val_loss: 0.4412
# Epoch 10/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8947 - val_loss: 0.4514

# %%
# Save the model
model.save("flower_classifier.keras")

# %%
# Predict on a batch of images
for images, labels in validation_dataset.take(1):
    predictions = model.predict(images)
    for i in range(5):  # Display first 5 images
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(f"Predicted: {'Sunflower' if predictions[i] <= 0.5 else 'Tulip'}, Actual: {class_names[int(labels[i])]}")
        plt.axis("off")
        plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
